# %%
pip install GEOS
# Out:
# Requirement already satisfied: GEOS in c:\users\vyome\anaconda3\lib\site-packages (0.2.3)
# Requirement already satisfied: flask in c:\users\vyome\anaconda3\lib\site-packages (from GEOS) (1.1.2)
# Requirement already satisfied: pillow in c:\users\vyome\anaconda3\lib\site-packages (from GEOS) (9.0.1)
# Requirement already satisfied: lxml in c:\users\vyome\anaconda3\lib\site-packages (from GEOS) (4.8.0)
# Requirement already satisfied: click>=5.1 in c:\users\vyome\anaconda3\lib\site-packages (from flask->GEOS) (8.0.4)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\vyome\anaconda3\lib\site-packages (from flask->GEOS) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\vyome\anaconda3\lib\site-packages (from flask->GEOS) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\vyome\anaconda3\lib\site-packages (from flask->GEOS) (2.11.3)
# Requirement already satisfied: colorama in c:\users\vyome\anaconda3\lib\site-packages (from click>=5.1->flask->GEOS) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vyome\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->GEOS) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install basemap
# Out:
# Requirement already satisfied: basemap in c:\users\vyome\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: matplotlib<3.6,>=1.5 in c:\users\vyome\anaconda3\lib\site-packages (from basemap) (3.5.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\vyome\anaconda3\lib\site-packages (from basemap) (1.23.3)
# Requirement already satisfied: pyproj<3.4.0,>=1.9.3 in c:\users\vyome\anaconda3\lib\site-packages (from basemap) (3.3.1)
# Requirement already satisfied: pyshp<2.4,>=1.2 in c:\users\vyome\anaconda3\lib\site-packages (from basemap) (2.3.1)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in c:\users\vyome\anaconda3\lib\site-packages (from basemap) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyome\anaconda3\lib\site-packages (from matplotlib<3.6,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in c:\users\vyome\anaconda3\lib\site-packages (from pyproj<3.4.0,>=1.9.3->basemap) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\vyome\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.6,>=1.5->basemap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge basemap
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\vyome\anaconda3\pkgs'

# %%
from mpl_toolkits.basemap import Basemap

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))
m = Basemap(projection = "mill")
# Coastal map
m.drawcoastlines()

plt.title("my world", fontsize = 20)
plt.savefig("Coastal Map")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map_1")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = 0,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = 0,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map_2")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 0,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 0    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map_3")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Countries
m.drawcountries(color = "blue")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Countries")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Countries
# m.drawcountries(color = "blue")
# States
m.drawstates(color = "red")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With States")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Countries
m.drawcountries(color = "blue")
# States
m.drawstates(color = "red")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Countries & States")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Rivers
m.drawrivers(color = 'blue')

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Rivers")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Map Boundary
m.drawmapboundary(color = "pink", linewidth = 10, fill_color = "aqua")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Boundary")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Map Boundary
# m.drawmapboundary(color = "pink", linewidth = 10, fill_color = "aqua")
# Continents
m.fillcontinents(color = "lightgreen", lake_color = "blue")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Continents")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Map Boundary
m.drawmapboundary(color = "pink", linewidth = 10, fill_color = "aqua")
# Continents
m.fillcontinents(color = "lightgreen", lake_color = "blue")

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Boundary & Continents")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# etopo Map Background
m.etopo()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With ETOPO Background")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# bluemarble Map Background
m.bluemarble()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Bluemarble Background")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# shadedrelief Map Background
m.shadedrelief()

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Shadedrelief Background")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Parallels (Horizontal Lines)
m.drawparallels(np.arange(-90, 90, 10), labels = [True, False, False, False])

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Horizontal Parallels Lines")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Parallels (Horizontal Lines)
# m.drawparallels(np.arange(-90, 90, 10), labels = [True, False, False, False])
# Meridians (Vertical Lines)
m.drawmeridians(np.arange(-180, 180, 30), labels = [0, 0, 0, 1])

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Vertical Meridians Lines")
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# For setting map size
plt.figure(figsize=(12, 9))

m = Basemap(projection = "mill",
           llcrnrlat = -90,   # Lower Left Corner Latitude
           urcrnrlat = 90,    # Upper Right Corner Latitude
           llcrnrlon = -180,  # Lower Left Corner Longitude
           urcrnrlon = 180    # Upper Right Corner Longitude
           )
# Coastal map
m.drawcoastlines()
# Parallels (Horizontal Lines)
m.drawparallels(np.arange(-90, 90, 10), labels = [True, False, False, False])
# Meridians (Vertical Lines)
m.drawmeridians(np.arange(-180, 180, 30), labels = [0, 0, 0, 1])

plt.title("My World", fontsize = 20)
plt.savefig("Coastal Map With Horizontal Parallels Lines & Vertical Meridians Lines")
plt.show()
